# %%
import os

path = "/home/ceadmin/Desktop/aca/aca-lab-module2/mibench/benchmark"

#Binaries to be be used for benchmarking generated by simplescalar
program_binary = [
		"search_large",
		"susan_smoothing",
		"susan_edges",
		"susan_corners",
		"lame",
		"rawcaudio",
		"rawdaudio"]

#Commands to be be appended for benchmarking generated by simplescalar
program_binary_cmds = [
			"./search_large > output_large.txt",
			"./susan input_large.pgm output large.smoothing.pgm -s",
			"./susan input_large.pgm output large.edges.pgm -e",
			"./susan input_large.pgm output large.corners.pgm -c",
			"./lame small.wav output_small.mp3",
			"./rawcaudio < large.pcm > output_large.adpcm",
			"./rawdaudio < large.adpcm > output_large.pcm"]

base_cmd = "sim-outorder"
redir_io = "-redir:sim"

fetch_ifqsize 	= ["8"]
decode_width 		= ["8"]
issue_width 		= ["8"]
lsq_size 				= ["4","8"]
ruu_size 				= ["4"]
res_ialu 				= ["4","8"]
res_imult 			= ["4","8"]
res_fpalu 			= ["1","8"]
res_fpmult 			= ["1","8"]
commit_width 		= ["4","8"]
issue_inorder 	= ["false"]
bpred 					= ["bimod"]

#OPTIONS FOR PARAMETERS
#fetch_ifqsize 	= ["1","2","4","8"]
#decode_width 	= ["1","2","4","8"]
#issue_width 	= ["1","2","4","8"]
#lsq_size 	= ["4","8"]
#ruu_size 	= ["4","8"]
#res_ialu 	= ["1","2","4","8"]
#res_imult 	= ["1","2","4","8"]
#res_fpalu 	= ["1","2","4","8"]
#res_fpmult 	= ["1","2","4","8"]
#commit_width 	= ["1","2","4","8"]
#issue_inorder 	= ["true","false"]
#bpred 		= ["taken","notaken","bimod"]

fetch_ifqsize_parameter = "-fetch:ifqsize"
decode_width_parameter 	= "-decode:width"
issue_width_parameter 	= "-issue:width"
lsq_size_parameter 	= "-lsq:size"
ruu_size_parameter 	= "-ruu:size"
res_ialu_parameter 	= "-res:ialu"
res_imult_parameter 	= "-res:imult"
res_fpalu_parameter 	= "-res:fpalu"
res_fpmult_parameter 	= "-res:fpmult"
commit_width_parameter 	= "-commit:width"
issue_inorder_parameter = "-issue:inorder"
bpred_parameter 	= "-bpred"

SPACE = " "
cnt = 0

total_string = ""

for i in range(0,len(program_binary)):
	for j in range(0,len(fetch_ifqsize)):
		for k in range(0,len(decode_width)):
			for l in range(0,len(issue_width)):
				for m in range(0,len(lsq_size)):
					for n in range(0,len(ruu_size)):
						for o in range(0,len(res_ialu)):
							for p in range(0,len(res_imult)):
								for q in range(0,len(res_fpalu)):
									for r in range(0,len(res_fpmult)):
										for s in range(0,len(commit_width)):
											for t in range(0,len(issue_inorder)):
												for u in range(0,len(bpred)):
													fetch_ifqsize_args = fetch_ifqsize_parameter + SPACE + fetch_ifqsize[j]
													decode_width_args  = decode_width_parameter  + SPACE + decode_width[k]
													issue_width_args = issue_width_parameter + SPACE + issue_width[l]
													lsq_size_args = lsq_size_parameter + SPACE + lsq_size[m]
													ruu_size_args = ruu_size_parameter + SPACE + ruu_size[n]
													res_ialu_args = res_ialu_parameter + SPACE + res_ialu[o]
													res_imult_args = res_imult_parameter + SPACE + res_imult[p]
													res_fpalu_args = res_fpalu_parameter + SPACE + res_fpalu[q]
													res_fpmult_args = res_fpmult_parameter + SPACE + res_fpmult[r]
													commit_width_args = commit_width_parameter + SPACE + commit_width[s]
													issue_inorder_args = issue_inorder_parameter + SPACE + issue_inorder[t]
													bpred_parameter_args = bpred_parameter + SPACE + bpred[u]
													outputfile = program_binary[i] + "_fetch" +  fetch_ifqsize[j] + "_decode" + decode_width[k] + "_isswidth" + issue_width[l] + "_lsq" + lsq_size[m] + "_ruu" + ruu_size[n] + "_ialu" + res_ialu[o] + "_imul" + res_imult[p] + "_fpalu" + res_fpalu[q] + "_fpmul" + res_fpmult[r] + "_comm" + commit_width[s] + "_issue_" + issue_inorder[t][0]+".txt"
													cmd = base_cmd + SPACE + redir_io + SPACE + outputfile + SPACE + fetch_ifqsize_args + SPACE + decode_width_args + SPACE + lsq_size_args + SPACE + ruu_size_args + SPACE + res_ialu_args + SPACE + res_imult_args + SPACE +  res_fpalu_args + SPACE +  res_fpmult_args + SPACE +  commit_width_args + SPACE +  issue_inorder_args + SPACE +  bpred_parameter_args + SPACE + program_binary_cmds[i]
													print(cmd)
													total_string += cmd + "\n"
													cnt += 1
													# Indicate Progress when executing the shell script
													print("echo {} {} generated".format(str(cnt),outputfile))
# Out:
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 1 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 2 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 3 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 4 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 5 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 6 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 7 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 8 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 9 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 10 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 11 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 12 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 13 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 14 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 15 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 16 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 17 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 18 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 19 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 20 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 21 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 22 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 23 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 24 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 25 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 26 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 27 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 28 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 29 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 30 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 31 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 32 search_large_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 33 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 34 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 35 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 36 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 37 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 38 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 39 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 40 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 41 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 42 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 43 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 44 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 45 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 46 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 47 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 48 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 49 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 50 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 51 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 52 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 53 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 54 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 55 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 56 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 57 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 58 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 59 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 60 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 61 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 62 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 63 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./search_large > output_large.txt
# echo 64 search_large_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 65 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 66 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 67 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 68 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 69 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 70 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 71 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 72 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul4_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 73 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 74 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 75 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 76 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 77 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 78 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 79 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 80 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu4_imul8_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 81 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 82 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 83 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 84 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 85 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 86 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 87 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 88 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul4_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 89 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 90 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 91 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 92 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 93 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 94 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 95 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 96 susan_smoothing_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 97 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 98 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 99 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 100 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 101 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 102 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 103 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 104 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 105 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 106 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 107 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 108 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 109 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 110 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./susan input_large.pgm output large.smoothing.pgm -s
# echo 111 susan_smoothing_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul8_comm4_issue_f.txt generated
# ...
# echo 411 rawdaudio_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 412 rawdaudio_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 413 rawdaudio_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 414 rawdaudio_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 415 rawdaudio_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 4 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 416 rawdaudio_fetch8_decode8_isswidth8_lsq4_ruu4_ialu8_imul8_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 417 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 418 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 419 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 420 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 421 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 422 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 423 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 424 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul4_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 425 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 426 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 427 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 428 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 429 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 430 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 431 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 4 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 432 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu4_imul8_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 433 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 434 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 435 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 436 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 437 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 438 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 439 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 4 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 440 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul4_fpalu8_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 441 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 442 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 443 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 1 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 444 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu1_fpmul8_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul1_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 445 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul1_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul1_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 1 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 446 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul1_comm8_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul8_comm4_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 4 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 447 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul8_comm4_issue_f.txt generated
# sim-outorder -redir:sim rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul8_comm8_issue_f.txt -fetch:ifqsize 8 -decode:width 8 -lsq:size 8 -ruu:size 4 -res:ialu 8 -res:imult 8 -res:fpalu 8 -res:fpmult 8 -commit:width 8 -issue:inorder false -bpred bimod ./rawdaudio < large.adpcm > output_large.pcm
# echo 448 rawdaudio_fetch8_decode8_isswidth8_lsq8_ruu4_ialu8_imul8_fpalu8_fpmul8_comm8_issue_f.txt generated
